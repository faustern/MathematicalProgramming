# %%
2 + 2
# Out:
# 4

# %%
3 * (4 + 5)
# Out:
# 27

# %%
2 ** 4
# Out:
# 16

# %%
2*3**3-3+4
# Out:
# 55

# %%
2 * (3**3) + (-3 + 4)
# Out:
# 55

# %%
(2 * (3**3)) + (-3 + 4)
# Out:
# 55

# %%
2**3**4
# Out:
# 2417851639229258349412352

# %%
(2**3)**4
# Out:
# 4096

# %%
2**(3**4)
# Out:
# 2417851639229258349412352

# %% [markdown]
# Make your codes clear. *Important:* We can use Latex here to create formulas. Above we calculated ${2^3}^4$ and also $2^{3^4}$

# %% [markdown]
# Exercise: calculate $$2^{9941}$$

# %%
2**9941
# Out:
# ...

# %%
2**9941 - 1
# Out:
# ...

# %% [markdown]
# **Prime number:** A number which is only divisible by 1 and itself...Example: 2, 7, 13

# %% [markdown]
# **Definition:** A prime number of the form $2^n-1$ is called Marsenne prime number...

# %% [markdown]
# Compute ${(5+{(4+{(3+{(2+1)}^2)}^2)}^2)}^2)$

# %%
(5+(4+(3+((2+1)**2))**2)**2)**2
# Out:
# 480004281

# %% [markdown]
# Compute the continuous fraction:
# $$6+\frac{1}{5+\frac{1}{4+\frac{1}{3+\frac{1}{2}}}}$$

# %%
1/(3+(1/2))
# Out:
# 0.2857142857142857

# %%
1/(4+_)
# Out:
# 0.23333333333333334

# %%
1/(5+_)
# Out:
# 0.19108280254777069

# %%
6+_
# Out:
# 6.191082802547771

# %%
_3
# Out:
# 480004281

# %% [markdown]
# Recall the integers $\mathbb Z=\{ \dots, -3,-2,-1,0, 1, 2, 3, \cdots$
# Natural numbers $\mathbb N = \{0, 1, 2, 3, \dots \}$
# Rational numbers... $\mathbb Q = \{3/4, 6/8, -12/24, \dots \}$
# then we have real numbers such as  $\pi$, or $e$

# %%
type(12)
# Out:
# int

# %%
type(-4)
# Out:
# int

# %%
type(3/4)
# Out:
# float

# %% [markdown]
# We have complex numbers... $2+3i$.. where $i^2 = -1$

# %%
2+3j
# Out:
# (2+3j)

# %%
type(2+3j)
# Out:
# complex

# %%
1j*1j
# Out:
# (-1+0j)

# %%
(2+4j)*(-4+3j)
# Out:
# (-20-10j)

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
(17 // 3) * 3 + 17 %3
# Out:
# 17

# %% [markdown]
# **Theorem** Let $m$ and $n$ be two numbers. Then $m = n q + r$ where $0 \leq r < n$

# %% [markdown]
# $m = 15$ and $n = 4$... then $q=3$ and $r=3$, ie.e, $15=4*3+3$ furthermore, $q$ and $r$ are unique.

# %%
4*3+3
# Out:
# 15

# %%
15 == 4*3+3
# Out:
# True

# %%
2**4 == 18
# Out:
# False

# %%
type(2 == 4)
# Out:
# bool

# %%
import math

# %%
math.sin(123)
# Out:
# -0.45990349068959124

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %% [markdown]
# math is a library which provides mathematical functions... numpy.. stands for numerical python...

# %%
import numpy

# %%
numpy.sin(numpy.pi/2)
# Out:
# 1.0

# %%
numpy.sin(numpy.pi)
# Out:
# 1.2246467991473532e-16

# %%
numpy.sin(numpy.pi/5)
# Out:
# 0.587785252292473

# %% [markdown]
# Calculate $$\sin(\frac{\pi}{5})$$

# %%
numpy.sin(numpy.pi/5)
# Out:
# 0.587785252292473

# %%
math.sin(math.pi/5)
# Out:
# 0.5877852522924731

# %%
import sympy

# %%
sympy.sin(sympy.pi/5)
# Out:
# sqrt(5/8 - sqrt(5)/8)

# %% [markdown]
# `sympy` library gives the precise value for $\sin(\frac{5}{2}$. This shows the library `sympy` does not approach calculations with approximation

# %% [markdown]
# ##Exercise:
# show $$\sin^2(\pi/5)+\cos^2(\pi/5)=1$$

# %%
numpy.sin(numpy.pi/5)**2 + numpy.cos(numpy.pi/5)**2
# Out:
# 1.0

# %%
math.sin(math.pi/5)**2 + math.cos(math.pi/5)**2
# Out:
# 1.0

# %%
sympy.sin(sympy.pi/5)**2 + sympy.cos(sympy.pi/5)**2
# Out:
# -sqrt(5)/8 + 5/8 + (1/4 + sqrt(5)/4)**2

# %%
sympy.simplify(_)
# Out:
# 1

# %%
import numpy as np

# %%
np.sin(np.pi)
# Out:
# 1.2246467991473532e-16

# %%
import numpy as wes

# %%
wes.sin(wes.pi)
# Out:
# 1.2246467991473532e-16

# %% [markdown]
# **Variables**

# %%
x= 12

# %%
x
# Out:
# 12

# %%
x
# Out:
# 12

# %%
x+16
# Out:
# 28

# %%
x=3.6

# %%
type(x)
# Out:
# float

# %%
y = 23

# %%
x+y
# Out:
# 26.6

# %%
x*y
# Out:
# 82.8

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
x = 6; y = -23; z = 'test'

# %%
type(y)
# Out:
# int

# %%
x + y
# Out:
# -17

# %%
a = 2

# %%
a = a + 10

# %%
a
# Out:
# 12

# %%
a = a ** 4

# %%
a
# Out:
# 20736

# %%
a = a + 1

# %%
a
# Out:
# 20737

# %%
a +=1

# %% [markdown]
# The expression `a +=1` stands for `a = a+1`.. in fact `a#=n` stands for `a = a#n`

# %%
a=10

# %%
a *= 5

# %%
a
# Out:
# 50

# %%
a %= 5

# %%
a
# Out:
# 0

# %%
xWSU = 12

# %%
xWSU
# Out:
# 12

# %%
xWSU * y
# Out:
# -276

# %%
x_interestrate = 5

# %%
x_interestrate
# Out:
# 5

# %%
xX=12

# %%
xx=14

# %%
xx == xX
# Out:
# False

# %% [markdown]
# Variable are case sensitive

# %%
x_profit = 12

# %%
x_profit + x_interestrate
# Out:
# 17

# %%
from PIL import Image

# %%
x = Image.open('N1.jpg')

# %%
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=340x559>

# %%
y = Image.open('N2.jpeg')

# %%
y
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=576x713>

# %% [markdown]
# **Boolean expression**

# %%
1 > 2
# Out:
# False

# %%
2 > 1
# Out:
# True

# %%
1 <= 3
# Out:
# True

# %%
25 % 2 == 1
# Out:
# True

# %%
x = 5

# %%
x < 6
# Out:
# True

# %%
(x < 6) or (x>10)
# Out:
# True

# %%
(x < 6) and (x>10)
# Out:
# False

# %%
not (True)
# Out:
# False

# %%
not (False)
# Out:
# True

# %%
not (x < 10)
# Out:
# False

# %%
1 < x < 4
# Out:
# False

# %%
1 < x < 10
# Out:
# True

# %%
'this is a string'
# Out:
# 'this is a string'

# %%
x = 'this is a string'

# %%
x
# Out:
# 'this is a string'

# %%
'test' == 'this'
# Out:
# False

# %%
'test' == "test"
# Out:
# True

# %%
x = 'Western Sydney University'

# %%
x
# Out:
# 'Western Sydney University'

# %%
type(x)
# Out:
# str

# %%
len(x)
# Out:
# 25

# %% [markdown]
# **Using objects and methods**

# %%
x
# Out:
# 'Western Sydney University'

# %%
x.upper()
# Out:
# 'WESTERN SYDNEY UNIVERSITY'

# %%
'tstststst'.upper()
# Out:
# 'TSTSTSTST'

# %%
x.lower()
# Out:
# 'western sydney university'

# %%
x
# Out:
# 'Western Sydney University'

# %%
x = x.upper()

# %%
x
# Out:
# 'WESTERN SYDNEY UNIVERSITY'

# %%
x.capitalize()
# Out:
# 'Western sydney university'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
'western ' + 'sydney'
# Out:
# 'western sydney'

# %%
x
# Out:
# 'WESTERN SYDNEY UNIVERSITY'

# %%
x*3
# Out:
# 'WESTERN SYDNEY UNIVERSITYWESTERN SYDNEY UNIVERSITYWESTERN SYDNEY UNIVERSITY'

# %%
 x + ' and ' + x.lower()
# Out:
# 'WESTERN SYDNEY UNIVERSITY and western sydney university'

# %%
x[0]
# Out:
# 'W'

# %%
x[1]
# Out:
# 'E'

# %%
x[6]
# Out:
# 'N'

# %%
x[-1]
# Out:
# 'Y'

# %%
x[-2]
# Out:
# 'T'

# %%
x[len(x)-3]
# Out:
# 'I'

# %% [markdown]
# A word is called *palandromic* if if it reads the same forward and backward

# %%
x='kayak'

# %%
x[0]==x[-1] and x[1]==x[-2] and x[2]==x[-3]
# Out:
# True

# %%
txt = "Western Sydney Oni"
mytable = txt.maketrans("O", "U")
print(txt.translate(mytable))
# Out:
# Western Sydney Uni

# %%
txt = "Hi Sam!"
x = "mSa"
y = "eJo"
mytable = txt.maketrans(x, y)
print(txt.translate(mytable))
# Out:
# Hi Joe!

# %%
x = Image.open('N1.jpg')

# %%
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=340x559>

# %%
x.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=340x559>

# %%
x.effect_spread(10)
# Out:
# <PIL.Image.Image image mode=RGB size=340x559>
